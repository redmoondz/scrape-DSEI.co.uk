# %% [markdown]
# # VR Weapons Training Scoring Pipeline
#
# ## Overview
# This pipeline scores defense companies based on their relevance to VR/AR/MR weapons and tactical training solutions.
#
# ## Scoring Logic
#
# **Total Score: 0-100 points**
#
# ### Scoring Criteria:
#
# 1. **Tags Analysis (30 points)**
#    - VR/AR/MR tags → +30 points
#
# 2. **Weapons Training Tags (25 points)**
#    - Weapons/Small Arms Training → +25 points
#
# 3. **Overview Keywords (45 points)**
#    - "VR" / "virtual reality" → +15 points
#    - "weapons" / "firearms" / "shooting" → +15 points
#    - "police" / "law enforcement" / "military training" → +10 points
#    - "tactical" / "combat simulation" → +5 points
#
# ### Relevance Categories:
#
# | Score Range | Category | Description |
# |-------------|----------|-------------|
# | 70-100 | **HIGH** | Direct VR weapons training provider |
# | 40-69 | **MEDIUM** | Partially relevant solution |
# | 0-39 | **LOW** | Not relevant |

# %%
import pandas as pd

df = pd.read_csv('/Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies.csv')

df.head(5)
# Out:
#                 company_name                  slug_name  \
# 0           "NT Service" UAB              nt-serviceuab
# 1       1MILLIKELVIN PTY LTD           1millikelvin-pty
# 2            2Excel Aviation            2excel-aviation
# 3                2T Security                2t-security
# 4  3A Composites Mobility AG  3a-composites-mobility-ag
#
#                                                  url    stand  \
# 0  https://www.dsei.co.uk/exhibitors-list/nt-serv...   N9-205
# 1  https://www.dsei.co.uk/exhibitors-list/1millik...   S2-110
# 2  https://www.dsei.co.uk/exhibitors-list/2excel-...   S3-165
# 3  https://www.dsei.co.uk/exhibitors-list/2t-secu...  S15-154
# 4  https://www.dsei.co.uk/exhibitors-list/3a-comp...   N9-150
#
#                                                 tags  \
# 0  Telecommunications; Communication Systems; Com...
# 1  Maintenance and Repair; Technical Services; Se...
# 2  Fixed Wing; Surveillance; Engineering Services...
# 3  Cloud and Infrastructure; Artificial Intellige...
# 4  Utility Vehicles; Emergency Vehicles; Rough Te...
#
#                                             overview  \
# 0  “NT SERVICE” a Lithuania based company with 27...
# 1  1MILLIKELVIN are an innovative Australian manu...
# 2  2Excel is an innovative aviation and aerospace...
# 3  2T Security provides agile, field-ready cyber ...
# 4  3A Composites Mobility: Advanced Lightweight S...
#
#                          website
# 0                            NaN
# 1    http://www.1millikelvin.com
# 2  http://www.2excelaviation.com
# 3             http://2T Security
# 4         http://Park Altenrhein

# %%
# Check dataset structure
print("Columns:", df.columns.tolist())
print("\nShape:", df.shape)
print("\nSample tags:", df['tags'].head(3).tolist() if 'tags' in df.columns else "No tags column")
print("\nSample overview:", df['overview'].head(1).tolist() if 'overview' in df.columns else "No overview column")
# Out:
# Columns: ['company_name', 'slug_name', 'url', 'stand', 'tags', 'overview', 'website']
#
# Shape: (1733, 7)
#
# Sample tags: ['Telecommunications; Communication Systems; Command and Control; Countermeasures; Electronic Warfare; Counter UAV', 'Maintenance and Repair; Technical Services; Sensors; Infrared Technologies; Test Equipment and Facilities', 'Fixed Wing; Surveillance; Engineering Services; Furnishing and Fixings; Electrical Components and Subcomponents; Avionics; Sensing Technologies; Unmanned and Autonomous; Fixed Wing Aircraft Simulation and Training']
#
# Sample overview: ['“NT SERVICE” a Lithuania based company with 27 years of industry experience in designing, implementing and servicing of communication and IT solutions for public, private and critical infrastructure networks.  “NT SERVICE” presents and manufactures Multi-dimensional security solutions for defense and public safety authorities. We put our best effort to meet the most demanding market requirements for Counter UAV products/solutions (C-UAV/Jammer). Constantly growing demand and customer feedback motivates us continuously to improve our portable and fixed C-UAV products for inflicting a reliable blow against hostile drones/UAV.  Our battle proven SKYWIPER series systems are successfully and constantly used all over the world during official events for VIP protection, for state border controlling, police, prisons and military applications.']

# %%
# Get all unique tags from dataset
all_tags = df['tags'].dropna().str.split(';').explode().str.strip().unique()
all_tags_sorted = sorted(all_tags)
print(f"Total unique tags: {len(all_tags_sorted)}\n")
for tag in all_tags_sorted:
    print(f"- {tag}")
# Out:
# Total unique tags: 374
#
# - Access Management
# - Accessories
# - Active Microwave Technologies
# - Actuators
# - Additive Manufacturing
# - Adhesive Bonding
# - Adhesives
# - Air Platforms
# - Aircraft
# - Airfield and Air Traffic Control Services
# - Ammunition
# - Amphibious Vehicles
# - Anchor
# - Antennas
# - Anti-Aircraft
# - Anti-Ship and Submarine
# - Anti-Tank and Mines
# - Architectures and Systems
# - Armour
# - Armouring
# - Artificial Intelligence
# - Artificial Intelligence (AI)
# - Artillery
# - Assembly
# - Asset Tracking
# - Augmented Reality (AR) / Virtual Reality (VR) / Mixed Reality (MR)
# - Augmented Reality (AR) / Virtual Reality (VR) / Mixed Reality (MR) Based Training
# - Augmented Service Technologies
# - Automated Materials Handling
# - Auxiliary power unit (APU)
# - Avionics
# - Ballistic Protection
# - Base and Camp Protection and Security
# - Batteries
# - Battlefield Digitisation
# - Battlefield Support
# - Biometrics
# - Biotechnology
# - Boats
# - Bodies and Panels
# - Bomb Disposal (Explosive Ordnance Displosal - EOD / Improvised Explosive Device Displosal - IEDD)
# - Brakes
# - Breathing Apparatus
# - Building Equipment
# - Building Materials
# - Bulkheads and Skins
# - CNC Machining
# - Cabin Management
# - Cables and Wires
# - Camouflage
# - Carriage and Mounts
# - Casting
# - Castings
# - Catering Equipment
# - Ceramics
# - Chemical Manufacturing
# - Chemicals
# - Circuit Boards
# - Circuit Card Assemblies
# - Civil Protection and Disaster Management Readiness
# - Clothing
# - Cloud Services
# - Cloud and Infrastructure
# - Coatings
# - Collaboration Systems
# - Combat Identification
# - Command and Control
# - Communication Systems
# - Communications
# - Component Technologies
# - Components & Systems
# - Composites
# - Computers (laptops)
# - Construction
# - Consultancy
# - Consumable Materials
# - Control Systems
# - Counter UAV
# - Counter-IED Training and Simulation
# - Countermeasures
# - Cyber Security
# - Data Analytics
# - Data Management
# - Data Protection
# - Design
# - Design and Information Management Software
# - Design and Management Performance
# - Detection and Tracking
# - Device Security and Antivirus
# - Digital Services
# - Digital Twins
# - Directed Energy (Lasers)
# - Doors and Hatches
# - Drones
# - Dual-Use
# - Ducts
# - E-Learning
# - Electrical Components and Subcomponents
# - Electrical Systems
# - Electrical and Power and Battery
# - Electronic Warfare
# - Emergency Vehicles
# - Engine and Engine Control
# - Engineering
# - Engineering Services
# - Engines
# - Environmental
# - Equipment and Furnishing
# - Exhaust
# - Explosive Search Equipment
# - Explosives
# - Explosives and Disposal
# - Fabrication
# - Facilities Management
# - Fastening
# - Fibre Optics
# - Field Hospital Equipment and Services
# - Field Medicine
# - Filters
# - Financial Planning
# - Finishing
# - Fire Management
# - Fixed Wing
# - Fixed Wing Aircraft Simulation and Training
# - Flares
# - Flight Control
# - Fluid Power Systems
# - Food & Rations
# - Footwear
# - Forging
# - Forming
# - Freight
# - Fuel
# - Fuel Systems
# - Fuel and Oil Systems
# - Furnishing and Fixings
# - Fuselage
# - Galleys
# - Games
# - Geospatial
# - Glass
# - Global Navigaction Satellite System (GNSS) Technologies
# - Global Positioning System (GPS)
# - Goggles
# - Grenades and Mortars and Discharges
# - Ground Based Technologies
# - Ground Segment Technologies
# - Ground Support Equipment
# - Guided Weapons
# - Handling
# - Hardware
# - Harnesses and Climbing Equipment and Ropes
# - Heat Exchangers
# - Helicopter Landing Grids
# - Helicopters
# - Helm and Steering
# - Helmets
# - Hull
# - Hypersonics
# - IT Services
# - Identification Friend or Foe (IFF)
# - Identity Management
# - Identity and Access
# - Imaging
# - Imaging and Image Capture
# - Imaging and Visual
# - In-Orbit Propulsion
# - In-Situ Technologies
# - In-Space Technologies
# - Incident Management Training and Simulation
# - Information Technology
# - Infrared Technologies
# - Installation and Maintenance
# - Instruments
# - Insulation
# - Investment and Funding
# - Joining
# - Land Platforms
# - Landing Systems
# - Launch Platforms
# - Launch and Recovery
# - Launchers
# - Lidar Technologies
# - Life Rafts and Deployment
# - Lifebelts
# - Lighting
# - Lights
# - Logistics
# - Lorries
# - Machine Learning
# - Machining
# - Maintenance
# - Maintenance Repair Overhaul and Upgrades (MRO&U)
# - Maintenance and Diagnostics Training
# - Maintenance and Repair
# - Manufacturing Processes
# - Masks
# - Masts and Towers
# - Materials
# - Mechanical
# - Mechanical Components and Subcomponents
# - Mechanical Equipment
# - Mechanical Parts
# - Mechanical Services
# - Medical
# - Medical Equipment
# - Medical Training and Simulation
# - Medivac Providers
# - Metallurgy
# - Metals
# - Metaverse
# - Microelectronics
# - Missiles
# - Mission Computing
# - Mobile Learning Technologies
# - Modelling and Simulation
# - Mortars
# - Motors
# - Moulding
# - Nanotechnology
# - Naval Platforms
# - Naval and Subsea - Training and Simulation
# - Navigation Systems
# - Network Security
# - Night Vision
# - Nozzle
# - Nuclear Engineering
# - Oils and Lubricants
# - Optical
# - Optical Systems
# - Optronics
# - Oscillators
# - Passive Microwave Technologies
# - Patrol
# - Payload Accommodation and Integration
# - Perception Systems
# - Personal and Protection Equipment
# - Platform Interiors
# - Platform Structures
# - Platform Systems
# - Pneumatic and Hydraulic and Vaccuum
# - Polymers and Plastics
# - Power Supplies
# - Power Supplies and Batteries
# - Professional Services
# - Propellants
# - Propulsion
# - Protective Clothing
# - Pumps
# - Pyrotechnics
# - Quantum Computing
# - Quantum Technologies
# - Radar
# - Radar Technologies
# - Radio Frequency Identification (RFID)
# - Radio Frequency Sensing
# - Radios
# - Raw Materials
# - Receiver Technologies
# - Reflective and High Visibility
# - Refurbishment
# - Renewable
# - Rescue and Survival Equipment
# - Research
# - Rigging and Ropes
# - Riot Control and Crowd Control and Public Order
# - Robotics
# - Rocket Propulsion
# - Rockets
# - Rotary Training and Simulation
# - Rotary Wing
# - Rotor Blades and Propellers
# - Rough Terrain
# - Rubber Products
# - Rugged Computers
# - Safety and Survival
# - Satellite Antennas
# - Satellite Communication
# - Satellite Communications Payloads
# - Satellite Payloads
# - Satellite Spacecraft
# - Satellite Systems and Software
# - Satellite Telecommunications
# - Satellite Terminals
# - Satellites
# - Seals
# - Search and Rescue and Detection
# - Searchlights and Torches and Beacons and Illuminators and Markers
# - Seating
# - Security
# - Security Training Services
# - Semiconductors
# - Sensing Technologies
# - Sensor Technologies
# - Sensors
# - Services
# - Shields
# - Shipping
# - Ships
# - Sights
# - Simulation Systems Hardware
# - Small Arms Training and Simulation
# - Small Arms and Guns
# - Smart Dots
# - Smart Energy
# - Smart Energy Management
# - Smart Water
# - Software
# - Sonar
# - Sonar Technologies
# - Space Environment and Radiation
# - Space Platforms
# - Space Transport
# - Spacecraft
# - Spacecraft Subsystems
# - Spare Parts
# - Storage
# - Storage and Racking and Cabinets and Tanks and ISO and Containers
# - Storage and Stowage
# - Storage and Transport
# - Stowage and Cases
# - Subassemblies
# - Subcomponents
# - Submarines
# - Submersibles
# - Superstructure
# - Support Services
# - Support Technologies
# - Surveillance
# - Suspension
# - Synthetic Environments
# - Synthetic Fuel
# - Systems Engineering
# - Systems and Software
# - Targets and Decoys
# - Technical Services
# - Telecommunications
# - Test Equipment
# - Test Equipment and Facilities
# - Textiles
# - Tooling
# - Tracking Devices
# - Tracks
# - Trailers
# - Training and Education Services
# - Training and Simulation
# - Transmitters
# - Transportation
# - Tubes
# - Turret Subsystems
# - Turrets
# - Ultra-Violet (UV) and Visible Technologies
# - Uniform
# - Unmanned
# - Unmanned Systems Training and Simulation
# - Unmanned and Autonomous
# - Utility Vehicles
# - Valves
# - Vehicle Mounted Shelter
# - Vehicle and Alternatively Fuelled Vehicles (AFV) Training and Simulation
# - Vehicles
# - Warships
# - Water Management
# - Weapons
# - Weapons Training and Simulation
# - Wearable technology
# - Welding
# - Wet and Dry Suits
# - Wheels and Tyres
# - Windows and Windscreens and Glass
# - Wing and Wing Subcomponents
# - Wire Cutting and Stripping and Crimping
# - Workstations and Peripherals
# - X-ray and Gamma Ray Technologies

# %%
# Search for VR/AR/Training related tags
vr_related = [tag for tag in all_tags_sorted if any(kw in tag.lower() for kw in ['vr', 'virtual', 'ar', 'augment', 'mixed', 'xr', 'simulat', 'train', 'weapon', 'small arm', 'firearm', 'shoot', 'tactical', 'combat'])]
print("Tags potentially relevant to VR/Weapons Training:\n")
for tag in vr_related:
    print(f"- {tag}")
# Out:
# Tags potentially relevant to VR/Weapons Training:
#
# - Anti-Ship and Submarine
# - Architectures and Systems
# - Armour
# - Armouring
# - Artificial Intelligence
# - Artificial Intelligence (AI)
# - Artillery
# - Augmented Reality (AR) / Virtual Reality (VR) / Mixed Reality (MR)
# - Augmented Reality (AR) / Virtual Reality (VR) / Mixed Reality (MR) Based Training
# - Augmented Service Technologies
# - Auxiliary power unit (APU)
# - Breathing Apparatus
# - Carriage and Mounts
# - Circuit Boards
# - Circuit Card Assemblies
# - Combat Identification
# - Counter-IED Training and Simulation
# - Design and Information Management Software
# - E-Learning
# - Electronic Warfare
# - Explosive Search Equipment
# - Fixed Wing Aircraft Simulation and Training
# - Flares
# - Footwear
# - Grenades and Mortars and Discharges
# - Guided Weapons
# - Hardware
# - Harnesses and Climbing Equipment and Ropes
# - Incident Management Training and Simulation
# - Infrared Technologies
# - Lidar Technologies
# - Machine Learning
# - Maintenance and Diagnostics Training
# - Mechanical Parts
# - Medical Training and Simulation
# - Mobile Learning Technologies
# - Modelling and Simulation
# - Mortars
# - Naval and Subsea - Training and Simulation
# - Nuclear Engineering
# - Radar
# - Radar Technologies
# - Research
# - Rotary Training and Simulation
# - Rotary Wing
# - Satellite Systems and Software
# - Search and Rescue and Detection
# - Searchlights and Torches and Beacons and Illuminators and Markers
# - Security Training Services
# - Simulation Systems Hardware
# - Small Arms Training and Simulation
# - Small Arms and Guns
# - Smart Dots
# - Smart Energy
# - Smart Energy Management
# - Smart Water
# - Software
# - Sonar
# - Sonar Technologies
# - Spare Parts
# - Submarines
# - Systems and Software
# - Targets and Decoys
# - Training and Education Services
# - Training and Simulation
# - Unmanned Systems Training and Simulation
# - Vehicle and Alternatively Fuelled Vehicles (AFV) Training and Simulation
# - Warships
# - Weapons
# - Weapons Training and Simulation
# - Wearable technology

# %% [markdown]
# ## Scoring Pipeline Implementation

# %%
# =============================================================================
# SCORING CONFIGURATION
# =============================================================================
# Easy to modify keywords and weights for future support

SCORING_CONFIG = {
    # Tags Analysis (max 30 points)
    # Based on actual dataset tags found
    "tags": {
        "vr_ar_mr": {
            "keywords": [
                # Exact tags from dataset
                "Augmented Reality (AR) / Virtual Reality (VR) / Mixed Reality (MR)",
                "Augmented Reality (AR) / Virtual Reality (VR) / Mixed Reality (MR) Based Training",
                # Partial matches
                "virtual reality", "augmented reality", "mixed reality",
                "vr", "ar", "mr", "xr",
                # Related
                "Modelling and Simulation",
                "Training and Simulation",
            ],
            "points": 30
        }
    },
    
    # Weapons Training Tags (max 25 points)
    # Based on actual dataset tags found
    "weapons_tags": {
        "keywords": [
            # Exact tags from dataset
            "Small Arms Training and Simulation",
            "Weapons Training and Simulation",
            "Small Arms and Guns",
            "Weapons",
            # Partial matches
            "weapons", "small arms", "firearms", "shooting", "marksmanship", "gunnery"
        ],
        "points": 25
    },
    
    # Overview Keywords Analysis (max 45 points)
    "overview": {
        "vr_keywords": {
            "keywords": ["vr", "virtual reality", "immersive", "simulation"],
            "points": 15
        },
        "weapons_keywords": {
            "keywords": ["weapons", "firearms", "shooting", "small arms", "gunnery"],
            "points": 15
        },
        "target_audience": {
            "keywords": ["police", "law enforcement", "military training", "armed forces"],
            "points": 10
        },
        "tactical_keywords": {
            "keywords": ["tactical", "combat simulation", "combat training", "tactical training"],
            "points": 5
        }
    }
}

# Relevance Categories
RELEVANCE_THRESHOLDS = {
    "HIGH": (70, 100),    # Direct VR weapons training provider
    "MEDIUM": (40, 69),   # Partially relevant solution
    "LOW": (0, 39)        # Not relevant
}

# %%
# =============================================================================
# SCORING FUNCTIONS
# =============================================================================

def check_keywords(text: str, keywords: list) -> bool:
    """Check if any keyword exists in text (case-insensitive)."""
    if pd.isna(text):
        return False
    text_lower = text.lower()
    return any(kw.lower() in text_lower for kw in keywords)


def score_tags_vr(tags: str) -> int:
    """Score VR/AR/MR tags (max 30 points)."""
    config = SCORING_CONFIG["tags"]["vr_ar_mr"]
    if check_keywords(tags, config["keywords"]):
        return config["points"]
    return 0


def score_tags_weapons(tags: str) -> int:
    """Score weapons training tags (max 25 points)."""
    config = SCORING_CONFIG["weapons_tags"]
    if check_keywords(tags, config["keywords"]):
        return config["points"]
    return 0


def score_overview(overview: str) -> dict:
    """
    Score overview text based on keywords.
    Returns dict with individual scores for transparency.
    """
    scores = {
        "vr_score": 0,
        "weapons_score": 0,
        "audience_score": 0,
        "tactical_score": 0
    }
    
    if pd.isna(overview):
        return scores
    
    config = SCORING_CONFIG["overview"]
    
    # VR keywords (+15 points)
    if check_keywords(overview, config["vr_keywords"]["keywords"]):
        scores["vr_score"] = config["vr_keywords"]["points"]
    
    # Weapons keywords (+15 points)
    if check_keywords(overview, config["weapons_keywords"]["keywords"]):
        scores["weapons_score"] = config["weapons_keywords"]["points"]
    
    # Target audience keywords (+10 points)
    if check_keywords(overview, config["target_audience"]["keywords"]):
        scores["audience_score"] = config["target_audience"]["points"]
    
    # Tactical keywords (+5 points)
    if check_keywords(overview, config["tactical_keywords"]["keywords"]):
        scores["tactical_score"] = config["tactical_keywords"]["points"]
    
    return scores


def get_relevance_category(score: int) -> str:
    """Determine relevance category based on total score."""
    for category, (min_score, max_score) in RELEVANCE_THRESHOLDS.items():
        if min_score <= score <= max_score:
            return category
    return "LOW"

# %%
# =============================================================================
# MAIN SCORING PIPELINE
# =============================================================================

def score_company(row: pd.Series) -> pd.Series:
    """
    Calculate all scores for a single company.
    Returns a Series with all scoring components.
    """
    # Tags scoring
    tags_vr_score = score_tags_vr(row.get("tags", ""))
    tags_weapons_score = score_tags_weapons(row.get("tags", ""))
    
    # Overview scoring
    overview_scores = score_overview(row.get("overview", ""))
    
    # Calculate total
    total_score = (
        tags_vr_score +
        tags_weapons_score +
        overview_scores["vr_score"] +
        overview_scores["weapons_score"] +
        overview_scores["audience_score"] +
        overview_scores["tactical_score"]
    )
    
    # Cap at 100
    total_score = min(total_score, 100)
    
    return pd.Series({
        "tags_vr_score": tags_vr_score,
        "tags_weapons_score": tags_weapons_score,
        "overview_vr_score": overview_scores["vr_score"],
        "overview_weapons_score": overview_scores["weapons_score"],
        "overview_audience_score": overview_scores["audience_score"],
        "overview_tactical_score": overview_scores["tactical_score"],
        "total_score": total_score,
        "relevance": get_relevance_category(total_score)
    })

# %% [markdown]
# ## Apply Scoring Pipeline

# %%
# Apply scoring to all companies
scores_df = df.apply(score_company, axis=1)

# Combine original data with scores
df_scored = pd.concat([df, scores_df], axis=1)

# Sort by total score (highest first)
df_scored = df_scored.sort_values("total_score", ascending=False)

print(f"✅ Scored {len(df_scored)} companies")
print(f"\nRelevance Distribution:")
print(df_scored["relevance"].value_counts())
# Out:
# ✅ Scored 1733 companies
#
# Relevance Distribution:
# relevance
# LOW       1512
# MEDIUM     175
# HIGH        46
# Name: count, dtype: int64

# %% [markdown]
# ## Results: Top Scored Companies

# %%
# Display top companies with score breakdown
display_cols = [
    "company_name", 
    "total_score", 
    "relevance",
    "tags_vr_score",
    "tags_weapons_score",
    "overview_vr_score",
    "overview_weapons_score",
    "overview_audience_score",
    "overview_tactical_score"
]

print("🏆 TOP 20 Companies by Score:\n")
df_scored[display_cols].head(20)
# Out:
# 🏆 TOP 20 Companies by Score:
#                             company_name  total_score relevance  \
# 1390                         Shoot House           95      HIGH
# 1119                 Operator XR Pty Ltd           90      HIGH
# 243   Bluedrop Training & Simulation Inc           85      HIGH
# 1394                           Sig Sauer           85      HIGH
# 216         BERETTA DEFENSE TECHNOLOGIES           80      HIGH
# 673                    Grovtec USA, Inc.           80      HIGH
# 700                  Heckler & Koch GmbH           80      HIGH
# 994                          Militec Ltd           80      HIGH
# 355              Colt Canada Corporation           80      HIGH
# 1008                                 MKE           80      HIGH
# 319                 Ceska zbrojovka a.s.           80      HIGH
# 1480                          STEYR ARMS           80      HIGH
# 417                       Daniel Defense           80      HIGH
# 825                            KALEKALIP           80      HIGH
# 1515                       TAGinn Europe           80      HIGH
# 356                     Colt CZ Group SE           80      HIGH
# 1340          SARSILMAZ SILAH SANAYI A.S           80      HIGH
# 823               KAC (Knights Armament)           80      HIGH
# 1643                                 UTM           80      HIGH
# 1644                             UTM Ltd           80      HIGH
#
#       tags_vr_score  tags_weapons_score  overview_vr_score  \
# 1390             30                  25                 15
# 1119             30                  25                 15
# 243              30                  25                 15
# 1394             30                  25                  0
# 216              30                  25                  0
# 673              30                  25                  0
# 700              30                  25                  0
# 994              30                  25                  0
# 355              30                  25                  0
# 1008             30                  25                  0
# 319              30                  25                  0
# 1480             30                  25                  0
# 417              30                  25                  0
# 825              30                  25                  0
# 1515             30                  25                 15
# 356              30                  25                  0
# 1340             30                  25                  0
# 823              30                  25                  0
# 1643             30                  25                  0
# 1644             30                  25                  0
#
#       overview_weapons_score  overview_audience_score  overview_tactical_score
# 1390                      15                       10                        0
# 1119                      15                        0                        5
# 243                       15                        0                        0
# 1394                      15                       10                        5
# 216                       15                       10                        0
# 673                       15                       10                        0
# 700                       15                       10                        0
# 994                       15                       10                        0
# 355                       15                       10                        0
# 1008                      15                       10                        0
# 319                       15                       10                        0
# 1480                      15                       10                        0
# 417                       15                       10                        0
# 825                       15                       10                        0
# 1515                       0                       10                        0
# 356                       15                       10                        0
# 1340                      15                       10                        0
# 823                       15                       10                        0
# 1643                      15                       10                        0
# 1644                      15                       10                        0

# %%
# Filter by relevance category
def get_companies_by_relevance(df: pd.DataFrame, relevance: str) -> pd.DataFrame:
    """Get companies filtered by relevance category."""
    return df[df["relevance"] == relevance][["company_name", "total_score", "website", "overview"]].copy()

# HIGH relevance companies (direct VR weapons training providers)
high_relevance = get_companies_by_relevance(df_scored, "HIGH")
print(f"🎯 HIGH Relevance Companies ({len(high_relevance)}):")
high_relevance
# Out:
# 🎯 HIGH Relevance Companies (46):
#                             company_name  total_score  \
# 1390                         Shoot House           95
# 1119                 Operator XR Pty Ltd           90
# 243   Bluedrop Training & Simulation Inc           85
# 1394                           Sig Sauer           85
# 216         BERETTA DEFENSE TECHNOLOGIES           80
# 673                    Grovtec USA, Inc.           80
# 700                  Heckler & Koch GmbH           80
# 994                          Militec Ltd           80
# 355              Colt Canada Corporation           80
# 1008                                 MKE           80
# 319                 Ceska zbrojovka a.s.           80
# 1480                          STEYR ARMS           80
# 417                       Daniel Defense           80
# 825                            KALEKALIP           80
# 1515                       TAGinn Europe           80
# 356                     Colt CZ Group SE           80
# 1340          SARSILMAZ SILAH SANAYI A.S           80
# 823               KAC (Knights Armament)           80
# 1643                                 UTM           80
# 1644                             UTM Ltd           80
# 1463                    Spuhr i Dalby AB           80
# 598                           FN HERSTAL           80
# 581                 FightLite Industries           80
# 567       Fabbrica d’Armi Pietro Beretta           80
# 674                          Grupo Oesía           75
# 1402     SimCentric Technologies Pty Ltd           75
# 245                 BlueRoom Simulations           75
# 1697                      Wescom Defence           75
# 639                         Georgia, USA           70
# 1332          SANDEEP METALCRAFT PVT LTD           70
# 1318                                Saab           70
# 453                          Dillon Aero           70
# 1244                   Radnor Range Ltd.           70
# 1228                        Pyser Optics           70
# 183                               B&T AG           70
# 461                                  DND           70
# 1038                               Nammo           70
# 187                   Bagira Systems B.V           70
# 1075        NonLethal Technologies, Inc.           70
# 1316                                 S36           70
# 454                      DIRICKX Systems           70
# 1722                         XR Training           70
# 931                               Magpul           70
# 226                      Bindig QSTP-LLC           70
# 922                           Maccaferri           70
# 818               John Cockerill Defense           70
#
#                                             website  \
# 1390                    http://www.shoothouse.co.uk
# 1119                        https://operatorxr.com/
# 243              http://katherinesmith@bluedrop.com
# 1394                        http://WWW.SIGSAUER.COM
# 216      https://www.berettadefensetechnologies.com
# 673                                             NaN
# 700                     http://www.heckler-koch.com
# 994                        http://www.militec.co.uk
# 355                       http://www.coltcanada.com
# 1008                         https://www.mke.gov.tr
# 319                       http://www.czfirearms.com
# 1480                      http://www.steyr-arms.com
# 417                    http://www.danieldefense.com
# 825                     http://www.kalekalip.com.tr
# 1515                          http://www.taginn.pro
# 356                      http://www.coltczgroup.com
# 1340                       http://www.sarsilmaz.com
# 823                                             NaN
# 1643                    http://www.utmworldwide.com
# 1644                      https://utmworldwide.com/
# 1463                       http://Terminalvaegen 19
# 598                        http://www.fnherstal.com
# 581                        http://WWW.FIGHTLITE.COM
# 567                 https://www.berettadefense.com/
# 674                       http://www.grupooesia.com
# 1402                         https://www.simct.com/
# 245                       http://www.blueroomxr.com
# 1697     http://Wilne Mill, Draycott Derby DE72 3QJ
# 639                          http://www.georgia.org
# 1332               http://www.sandeepmetalcraft.com
# 1318                            http://www.saab.com
# 453                       http://www.Dillonaero.com
# 1244                       http://www.radnor.org.uk
# 1228                     http://www.pyseroptics.com
# 183                                 http://bt-ag.ch
# 461                       http://www.dn-defence.com
# 1038                           http://www.nammo.com
# 187                      https://www.bagirasys.com/
# 1075           http://www.nonlethaltechnologies.com
# 1316                          http://www.s36.com.au
# 454                    https://dirickx-systems.com/
# 1722  https://www.xrtraining.io/Government-Entities
# 931                           http://www.magpul.com
# 226                        http://www.bindig.com.qa
# 922                       http://www.maccaferri.com
# 818           https://defense.johncockerill.com/en/
#
#                                                overview
# 1390  ShootHouse is a leading provider of cutting-ed...
# 1119  Operator XR provides a complete VR solution fo...
# 243   Bluedrop is a Canadian-based leader in advance...
# 1394  SIG SAUER, Inc. is a leading provider and manu...
# 216   Beretta Defense Technologies (BDT) is the stra...
# 673   GrovTec is a U.S. manufacturer dedicated to de...
# 700   Heckler & Koch: Perfection for more than 75 ye...
# 994   Founded in 1997, Militec Ltd specialise in the...
# 355   In 1976, Canada hired Diemaco Inc. to repair a...
# 1008  MAKİNE ve KİMYA ENDÜSTRİSİ (MKE) is a state-ow...
# 319   Ceska zbrojovka a.s. (CZ) is a premier manufac...
# 1480  Since its foundation in 1864, STEYR ARMS GmbH ...
# 417   Daniel Defense is a family owned firearms manu...
# 825   KALEKALIP, founded in Istanbul in 1969, specia...
# 1515  TAGinn Europe is a leading supplier of trainin...
# 356   Colt CZ Group SE, together with its subsidiari...
# 1340  SARSILMAZ has the ability to produce top of th...
# 823   Knight’s Armament Company is a premier U.S. de...
# 1643  UTM produces the world’s most advanced non-let...
# 1644  UTM produces the world’s most advanced non-let...
# 1463  Spuhr i Dalby AB is a Swedish manufacturer of ...
# 598   At FN, we design differently.  For over 135 ye...
# 581   FightLite® Industries is a division of ARES De...
# 567   BERETTA (Fabbrica d’Armi Pietro Beretta): The ...
# 674   Grupo Oesía is a Spanish multinational dedicat...
# 1402  Three Pillars - Live Fire Range Safety, Accred...
# 245   BlueRoom Simulations is an industry leader in ...
# 1697  Wescom Defence is a trusted global producer of...
# 639   Georgia, USA has a strong R&D and defense cont...
# 1332  Sandeep Metalcraft Pvt Ltd (SMPL) is an ISO 90...
# 1318  Saab is a leading defence and security company...
# 453   Dillon Aero, founded in 1989, is a global lead...
# 1244  Radnor is a UK MoD accredited independent test...
# 1228  Why Visit Stand N3-115?  At Stand N3-115, Pyse...
# 183   B&T AG is a Swiss producer of small arms, supp...
# 461   Dynamit Nobel Defence GmbH (DND) is a global l...
# 1038  Nammo is one of the world’s leading providers ...
# 187   Bagira Systems delivers advanced simulation an...
# 1075  NonLethal Technologies manufactures a wide ran...
# 1316  Design. Make. Innovate.  S36 is a high-tech en...
# 454   DIRICKX Systems FORCE PROTECTION. BY ENGINEERS...
# 1722  XR Training (XRT) specializes in developing cu...
# 931   Magpul was founded in 1999 with the idea of de...
# 226   Bindig, a joint venture between Barzan Holding...
# 922   Maccaferri is a global leader in civil and env...
# 818   With more than 200 years of experience, John C...

# %% [markdown]
# ## Export Scored Data

# %%
# Export scored data to CSV
output_path = "/Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_scored.csv"

df_scored.to_csv(output_path, index=False)
print(f"✅ Exported to: {output_path}")

# Also export HIGH relevance companies separately
high_output_path = "/Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_high_relevance.csv"
high_relevance.to_csv(high_output_path, index=False)
print(f"✅ HIGH relevance companies exported to: {high_output_path}")


# # Export to Excel with multiple sheets
# excel_output_path = "/Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_scored.xlsx"

# with pd.ExcelWriter(excel_output_path, engine='openpyxl') as writer:
#    df_scored.to_excel(writer, sheet_name='All Companies', index=False)
#    high_relevance.to_excel(writer, sheet_name='HIGH Relevance', index=False)

# print(f"✅ Excel file exported to: {excel_output_path}")
# Out:
# ✅ Exported to: /Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_scored.csv
# ✅ HIGH relevance companies exported to: /Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_high_relevance.csv
# ✅ Excel file exported to: /Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_scored.xlsx
# ✅ Excel file exported to: /Users/s.rublivskyi/Documents/Dev/scrape-DSEI.co.uk/data/processed/companies_scored.xlsx
